# %%
#Load Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
print("Done")
# Out:
# Done

# %%
#Load Data
df = pd.read_excel('./Hitters-Cleaned.xlsx', sheet_name='Sheet1')
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    315    81      7    24   38     39     14    3449    835      69    321
# 1    479   130     18    66   72     76      3    1624    457      63    224
# 2    496   141     20    65   78     37     11    5628   1575     225    828
# 3    321    87     10    39   42     30      2     396    101      12     48
# 4    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary
# 0   414     375      N        W      632       43      10   475.0
# 1   266     263      A        W      880       82      14   480.0
# 2   838     354      N        E      200       11       3   500.0
# 3    46      33      N        E      805       40       4    91.5
# 4   336     194      A        W      282      421      25   750.0

# %%
#Key Statistics (Numerical Columns only)
df.describe()
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  263.000000  263.000000  263.000000  263.000000  263.000000  263.000000
# mean   403.642586  107.828897   11.619772   54.745247   51.486692   41.114068
# std    147.307209   45.125326    8.757108   25.539816   25.882714   21.718056
# min     19.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    282.500000   71.500000    5.000000   33.500000   30.000000   23.000000
# 50%    413.000000  103.000000    9.000000   52.000000   47.000000   37.000000
# 75%    526.000000  141.500000   18.000000   73.000000   71.000000   57.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years        CAtBat        CHits      CHmRun        CRuns  \
# count  263.000000    263.000000   263.000000  263.000000   263.000000
# mean     7.311787   2657.543726   722.186312   69.239544   361.220532
# ...

# %%
#Key stattistics Transpose
df.describe().T
# Out:
#          count         mean          std   min    25%     50%     75%      max
# AtBat    263.0   403.642586   147.307209  19.0  282.5   413.0   526.0    687.0
# Hits     263.0   107.828897    45.125326   1.0   71.5   103.0   141.5    238.0
# HmRun    263.0    11.619772     8.757108   0.0    5.0     9.0    18.0     40.0
# Runs     263.0    54.745247    25.539816   0.0   33.5    52.0    73.0    130.0
# RBI      263.0    51.486692    25.882714   0.0   30.0    47.0    71.0    121.0
# Walks    263.0    41.114068    21.718056   0.0   23.0    37.0    57.0    105.0
# Years    263.0     7.311787     4.793616   1.0    4.0     6.0    10.0     24.0
# CAtBat   263.0  2657.543726  2286.582929  19.0  842.5  1931.0  3890.5  14053.0
# CHits    263.0   722.186312   648.199644   4.0  212.0   516.0  1054.0   4256.0
# CHmRun   263.0    69.239544    82.197581   0.0   15.0    40.0    92.5    548.0
# CRuns    263.0   361.220532   331.198571   2.0  105.5   250.0   497.5   2165.0
# ...

# %%
#Key Statistics of variable Runs
df['Runs'].describe()
# Out:
# count    263.000000
# mean      54.745247
# std       25.539816
# min        0.000000
# 25%       33.500000
# 50%       52.000000
# 75%       73.000000
# max      130.000000
# Name: Runs, dtype: float64

# %%
# box plot
df['Runs'].plot(kind='box',vert=False,figsize=(14,8))
# Out:
# <AxesSubplot:>

# %%
#plotting density curve
ax=df['Runs'].plot(kind='density',figsize=(14,6))

# %%
#key statistics of Cruns
df['CRuns'].describe()
# Out:
# count     263.000000
# mean      361.220532
# std       331.198571
# min         2.000000
# 25%       105.500000
# 50%       250.000000
# 75%       497.500000
# max      2165.000000
# Name: CRuns, dtype: float64

# %%
#plotting density curve
ax=df['CRuns'].plot(kind='density',figsize=(14,6))

# %%
#Key statistics of HmRun 
df['HmRun'].describe()
# Out:
# count    263.000000
# mean      11.619772
# std        8.757108
# min        0.000000
# 25%        5.000000
# 50%        9.000000
# 75%       18.000000
# max       40.000000
# Name: HmRun, dtype: float64

# %%
#plotting density curve
ax=df['HmRun'].plot(kind='density',figsize=(14,6))

# %%
#key stats of CHmRun
df['CHmRun'].describe()
# Out:
# count    263.000000
# mean      69.239544
# std       82.197581
# min        0.000000
# 25%       15.000000
# 50%       40.000000
# 75%       92.500000
# max      548.000000
# Name: CHmRun, dtype: float64

# %%
#Plotting Density curve
ax=df['CHmRun'].plot(kind='density',figsize=(14,6))
